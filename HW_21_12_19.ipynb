# %% [markdown]
# Динамика тела в электромагнитном подвесе описывается следующей
# системой дифференциальных уравнений:
#
#
# $\begin{cases}
# \dot{x_{1}} = x_{2}\\
# \dot{x_{2}} = \frac{1}{2} \frac{(1 + x_{3})^{2}}{(1 - x_{1})^{2}} - 1 \\
# \dot{x_{3}} = - \frac{1 + x_{3}}{1 - x_{1}}x_{2} - a(1 - x_{1})x_{3} + (1 - x_{1})u
# \end{cases}$,
#
# где параметр $𝑎 = 5$ отвечает за отношение характерного времени «механической» части системы к характерному времени «электрической» части.
#
# Данная система имеет единственное неустойчивое состояние равновесия в точке $(0, 0, 0)$. Линеаризуем данную систему в окрестности состояния равновесия:
#
# $\begin{cases}
# \dot{x_{1}} = x_{2}\\
# \dot{x_{2}} = x_{1} + x_{3} \\
# \dot{x_{3}} = - x_{2} - ax_{3} + u
# \end{cases}$
#
# В этом случае:
#
# $A = \left[\begin{matrix}0 & 1 & 0\\1 & 0 & 1\\0 & -1 & -5\end{matrix}\right]$, $B = \left[\begin{matrix}0\\0\\1\end{matrix}\right]$
#
# Перейдем от непрерывной системы к дискретной по следующей формуле:
#
# $\xi_{k + 1} = e^{A(t_{k + 1} - t_{k})}\xi{k} + \int_{t_{k}}^{t_{k+1}}e^{A(t_{k + 1} - s)}Bu(s)ds$,
#
# считая, что управление является кусочнно постоянной функцией, то есть $u(t) = u_{k} = const$ при $t_k \leq t < t_{k + 1}$ и $t_{k + 1} - t_k = h = const$.
#
# Исходя из вышеописанного, получаем:
#
# $\xi_{k + 1} = e^{Ah}\xi{k} + \int_{t_{k}}^{t_{k+1}}e^{A(t_{k + 1} - s)}ds Bu_{k}$.
#
# Берем полученный интеграл, сделав перед этим замену $v = t_{k + 1} - s$ и пересчитав пределы интегрирования:
#
# $\xi_{k + 1} = e^{Ah}\xi{k} + \int_0^he^{Av}dv Bu_{k} = e^{Ah}\xi{k} + A^{-1}(e^{Ah} - I)Bu_{k}$. Мы знаем, что при такой схеме дискретизации все свойства системы сохраняются.
#
# Для получения окончательного вида нашей дискретной системы посчитаем матрицы, стоящие при $\xi{k}$ и $u_{k}$:
#
# Для этого нам потребуется посчитать матричную экспоненту $e^{Ah}$, воспользовавшись следующим свойством:
#
# $e^A = Se^DS^{-1}$, где $A = Ah$, $D$ - диагональная матрица с собственными числами матрицы $Ah$, а $S$ - матрица, составленная из собственных векторов.
#
# Далее, для большей определенности, возьмем $h = 0.1$.
#
# Найдем собственные числа матрицы $A$.
#
# Они были нам известны из условия задачи, умножим их на $h$:
#
# $\lambda_{1} \approx -0.4781, \lambda_{2} \approx -0.1138, \lambda_{3} \approx 0.0919$
#
# Далее найдем собственные векторы, чтобы составить матрицу $S$:
#
# $V_{1} = \left[\begin{matrix}0.046\\-0.219\\1\end{matrix}\right]$
#
# $V_{2} = \left[\begin{matrix}3.394\\-3.862\\1\end{matrix}\right]$
#
# $V_{3} = \left[\begin{matrix}-6.439\\-5.919\\1\end{matrix}\right]$
#
# Составляем матрицу $S$:
#
# $S = \left[\begin{matrix}0.046 & 3.394 & -6.439\\-0.219 & -3.862 & -5.919\\1 & 1 & 1\end{matrix}\right]$
#
# Найдем обратную матрицу $S^{-1}$:
#
# $S^{-1} = \left[\begin{matrix}-0.048 & 0.23 & 1.053\\0.133 & -0.152 & -0.039\\-0.085 & -0.078 & -0.013\end{matrix}\right]$
#
# У нас есть все, чтобы посчитать матричную экспоненту $e^A$. Сделаем это:
#
# $e^A = \left[\begin{matrix}0.046 & 3.394 & -6.439\\-0.219 & -3.862 & -5.919\\1 & 1 & 1\end{matrix}\right] \left[\begin{matrix}e^{-4.781} & 0 & 0\\0 & e^{-1.138} & 0\\0 & 0 & e^{0.919}\end{matrix}\right] \left[\begin{matrix}-0.048 & 0.23 & 1.053\\0.133 & -0.152 & -0.039\\-0.085 & -0.078 & -0.013\end{matrix}\right] = \left[\begin{matrix}0.029 & 3.029 & -7.059\\-0.136 & -3.447 & -6.489\\0.62 & 0.892 & 1.096\end{matrix}\right] \left[\begin{matrix}-0.048 & 0.23 & 1.053\\0.133 & -0.152 & -0.039\\-0.085 & -0.078 & -0.013\end{matrix}\right] = \left[\begin{matrix}1.001 & 0.097 & 0.004\\0.099 & 0.999 & 0.076\\-0.004 & -0.079 & 0.604\end{matrix}\right] = \hat{A}$
#
# Теперь найдем матрицу, стоящую при $u_{k}$:
#
# $A^{-1}(e^{A} - I)B = \left[\begin{matrix}0.2 & 1 & 0.2\\1 & 0 & 0\\-0.2 & 0 & -0.2\end{matrix}\right] \left[\begin{matrix}0.001 & 0.097 & 0.004\\0.099 & -0.001 & 0.076\\-0.004 & -0.079 & -0.396\end{matrix}\right]\left[\begin{matrix}0\\0\\1\end{matrix}\right] =  \left[\begin{matrix}0.099 & 0.003 & -0.003\\0.001 & 0.097 & 0.004\\0.0007 & -0.004 & 0.078\end{matrix}\right] \left[\begin{matrix}0\\0\\1\end{matrix}\right] = \left[\begin{matrix}-0.003\\0.004\\0.078\end{matrix}\right] = \hat{B}$
#
# Итого, наша дискретная система после округления имеет вид:
#
# $\xi_{k+1} = \left[\begin{matrix}1 & 0.1 & 0\\0.1 & 1 & 0.08\\0 & -0.08 & 0.6\end{matrix}\right]\xi_{k} + \left[\begin{matrix}0\\0\\0.08\end{matrix}\right]u_{k}$
#
# Или:
#
# $\begin{cases}
# \xi_{1, k + 1} = \xi_{1, k} + 0.1 \xi_{2, k}\\
# \xi_{2, k + 1} = 0.1 \xi_{1, k} + \xi_{2, k} + 0.08 \xi_{3, k}\\
# \xi_{3, k + 1} = - 0.08 \xi_{2, k} + 0.6 \xi_{3, k} + 0.08 u_{k}
# \end{cases}$
#
# Проанализируем полученную дискретную систему:
#
# Собственные числа: $\lambda_1 \approx 0.618, \lambda_2 \approx 0.888, \lambda_3 \approx 1.094$
#
# Видим, что третье собственное число лежит вне единичного круга. Следовательно, оно неустойчиво.
#
# ###### Нужен код, показывающий, что без управления система улетает куда-то

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

matr = np.array([
        [1,0.1,0],
        [0.1,1,0.08],
        [0,-0.08,0.6]
                  ])

u = np.array([0,0,0])
n = 100
x = np.zeros((n,3))
x[0] = [1,1,1]

for i in range(1,n):
    x[i] = matr.dot(x[i-1]) + u * x[i-1]
    
t = np.arange(n)
plt.plot(t, x[:,0])
plt.plot(t, x[:,1])
plt.plot(t, x[:,2])
# Out:
# <img src="data:image/png;base64,..." width="640">
